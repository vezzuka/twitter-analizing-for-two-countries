# %%
# Import packages

import os
import pandas as pd

# %%
# Using OS library to call CLI commands in Python
tweet_count = 100
username = 'jack'

os.system(f'snscrape --jsonl --max-results {tweet_count} twitter-search "from:{username}"> user-tweets.json')
# Out:
# 0

# %%
tweets_df = pd.read_json('user-tweets.json', lines=True)

tweets_df
# Out:
#                              _type  \
# 0   snscrape.modules.twitter.Tweet
# 1   snscrape.modules.twitter.Tweet
# 2   snscrape.modules.twitter.Tweet
# 3   snscrape.modules.twitter.Tweet
# 4   snscrape.modules.twitter.Tweet
# ..                             ...
# 95  snscrape.modules.twitter.Tweet
# 96  snscrape.modules.twitter.Tweet
# 97  snscrape.modules.twitter.Tweet
# 98  snscrape.modules.twitter.Tweet
# 99  snscrape.modules.twitter.Tweet
#
#                                                   url  \
# 0   https://twitter.com/jack/status/15977356574092...
# 1   https://twitter.com/jack/status/15977121222296...
# 2   https://twitter.com/jack/status/15977091321525...
# 3   https://twitter.com/jack/status/15977054937070...
# 4   https://twitter.com/jack/status/15977049398447...
# ..                                                ...
# 95  https://twitter.com/jack/status/15930317254454...
# 96  https://twitter.com/jack/status/15930316664651...
# ...
