# %%
# Import libraries

import pandas as pd
import os

# %%
# Load raw data from scraping

tweets_raw = pd.read_csv('../data/tweets_raw.csv')
tweets_raw.head()
# Out:
#                             _type  \
# 0  snscrape.modules.twitter.Tweet
# 1  snscrape.modules.twitter.Tweet
# 2  snscrape.modules.twitter.Tweet
# 3  snscrape.modules.twitter.Tweet
# 4  snscrape.modules.twitter.Tweet
#
#                                                  url  \
# 0  https://twitter.com/elonmusk/status/1598004480...
# 1  https://twitter.com/elonmusk/status/1597982424...
# 2  https://twitter.com/elonmusk/status/1597887972...
# 3  https://twitter.com/elonmusk/status/1597878869...
# 4  https://twitter.com/elonmusk/status/1597873111...
#
#                         date  \
# 0  2022-11-30 17:22:12+00:00
# 1  2022-11-30 15:54:33+00:00
# 2  2022-11-30 09:39:14+00:00
# 3  2022-11-30 09:03:04+00:00
# 4  2022-11-30 08:40:11+00:00
#
#                                              content  \
# 0  @EvaFoxU @Reuters Exactly. The obvious reality...
# 1                   Update from @Neuralink at 6pm PT
# 2           @NorthmanTrader @vincent13031925 Exactly
# ...

# %%
# Data cleansing

# Drop NaN and other problematic data
tweets_dropnas = tweets_raw.dropna(subset=['replyCount']).drop(index=14215).drop(index=14208)

tweets_dropnas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15438 entries, 0 to 15447
# Data columns (total 31 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   _type             15438 non-null  object
#  1   url               15438 non-null  object
#  2   date              15438 non-null  object
#  3   content           15438 non-null  object
#  4   renderedContent   15438 non-null  object
#  5   id                15438 non-null  float64
#  6   user              15438 non-null  object
#  7   replyCount        15438 non-null  float64
#  8   retweetCount      15438 non-null  object
#  9   likeCount         15438 non-null  object
#  10  quoteCount        15438 non-null  object
#  11  conversationId    15438 non-null  object
#  12  lang              15438 non-null  object
#  13  source            15438 non-null  object
#  14  sourceUrl         15438 non-null  object
#  15  sourceLabel       15438 non-null  object
# ...

# %%
tweets_cols1 = tweets_dropnas[['name','user', 'date','category', 'id', 'content','lang', 'sourceLabel',
                           'inReplyToTweetId', 'inReplyToUser', 'mentionedUsers', 'hashtags', 'replyCount']]

tweets_cols_to_num = tweets_dropnas[['retweetCount','likeCount', 'quoteCount']].apply(pd.to_numeric, errors='coerce')

tweets_clean = pd.concat((tweets_cols1, tweets_cols_to_num), axis=1)

tweets_clean.to_csv('../data/tweets_clean.csv', index=False)

# %%
tweets_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15438 entries, 0 to 15447
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              15438 non-null  object
#  1   user              15438 non-null  object
#  2   date              15438 non-null  object
#  3   category          15438 non-null  object
#  4   id                15438 non-null  float64
#  5   content           15438 non-null  object
#  6   lang              15438 non-null  object
#  7   sourceLabel       15438 non-null  object
#  8   inReplyToTweetId  4579 non-null   float64
#  9   inReplyToUser     4579 non-null   object
#  10  mentionedUsers    6317 non-null   object
#  11  hashtags          1438 non-null   object
#  12  replyCount        15438 non-null  float64
#  13  retweetCount      15438 non-null  float64
#  14  likeCount         15438 non-null  float64
#  15  quoteCount        15438 non-null  float64
# ...
