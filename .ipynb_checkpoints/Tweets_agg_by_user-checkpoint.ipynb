# %%
# Import libraries

import pandas as pd

# %%
tweets_raw = pd.read_csv('./data/tweets_raw.csv')
tweets_raw.head()
# Out:
#                             _type  \
# 0  snscrape.modules.twitter.Tweet
# 1  snscrape.modules.twitter.Tweet
# 2  snscrape.modules.twitter.Tweet
# 3  snscrape.modules.twitter.Tweet
# 4  snscrape.modules.twitter.Tweet
#
#                                                  url  \
# 0  https://twitter.com/elonmusk/status/1598004480...
# 1  https://twitter.com/elonmusk/status/1597982424...
# 2  https://twitter.com/elonmusk/status/1597887972...
# 3  https://twitter.com/elonmusk/status/1597878869...
# 4  https://twitter.com/elonmusk/status/1597873111...
#
#                         date  \
# 0  2022-11-30 17:22:12+00:00
# 1  2022-11-30 15:54:33+00:00
# 2  2022-11-30 09:39:14+00:00
# 3  2022-11-30 09:03:04+00:00
# 4  2022-11-30 08:40:11+00:00
#
#                                              content  \
# 0  @EvaFoxU @Reuters Exactly. The obvious reality...
# 1                   Update from @Neuralink at 6pm PT
# 2           @NorthmanTrader @vincent13031925 Exactly
# ...

# %%
tweets_df = tweets_raw[['name','user', 'category', 'id', 'content', 
                        'replyCount', 'retweetCount', 'likeCount', 'quoteCount', 
                        'lang', 'sourceLabel', 'inReplyToTweetId', 'inReplyToUser', 'mentionedUsers', 'hashtags']]

#tweets_df.astype({'retweetCount': 'float', 'likeCount':'float'})
#tweets_df['retweets'] =  pd.to_numeric(, errors='coerce')

#, 'likeCount', 'quoteCount']] =

pd.to_numeric(tweets_df['retweetCount'], errors='coerce').sum()
# Out:
# 68708891.0

# %%
tweets_raw.dtypes
# Out:
# _type                object
# url                  object
# date                 object
# content              object
# renderedContent      object
# id                  float64
# user                 object
# replyCount          float64
# retweetCount         object
# likeCount            object
# quoteCount           object
# conversationId       object
# lang                 object
# source               object
# sourceUrl            object
# sourceLabel          object
# outlinks             object
# tcooutlinks          object
# media                object
# retweetedTweet       object
# quotedTweet          object
# inReplyToTweetId    float64
# inReplyToUser        object
# mentionedUsers       object
# coordinates          object
# place                object
# hashtags             object
# cashtags             object
# user_name            object
# category             object
# name                 object
# dtype: object

# %%
tweets_agg = tweets_df.groupby(['name']).agg({'id': 'count', 
                                               'hashtags': 'nunique', 
                                               #'replyCount': ['sum', 'mean'], 
                                               #'retweetCount': ['sum', 'mean'], 
                                               #'likeCount': ['sum', 'mean']
                                              })#.round(2)
tweets_agg.sort_values('id', ascending=False)
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# File ~/anaconda3/lib/python3.9/site-packages/pandas/core/groupby/groupby.py:1578, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1577 try:
# -> 1578     result = self.grouper._cython_operation(
#    1579         "aggregate", values, how, axis=data.ndim - 1, min_count=min_count
#    1580     )
#    1581 except NotImplementedError:
#    1582     # generally if we have numeric_only=False
#    1583     # and non-applicable functions
#    1584     # try to python agg
#    1585     # TODO: shouldn't min_count matter?
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/core/groupby/ops.py:939, in BaseGrouper._cython_operation(self, kind, values, how, axis, min_count, **kwargs)
#     938 ngroups = self.ngroups
# --> 939 return cy_op.cython_operation(
#     940     values=values,
#     941     axis=axis,
# ...
